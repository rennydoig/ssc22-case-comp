# %% [markdown]
# # Spatial autocorrelation
# * Guides with codes on https://geographicdata.science/book/notebooks/06_spatial_autocorrelation.html
# * Here we use data aggregated by CDUID
#     * /dataset/canada-census-division/CD-download-data.shp
# * Boundary data obtained from https://www12.statcan.gc.ca/census-recensement/2011/geo/bound-limit/bound-limit-2016-eng.cfm

# %%
# To do:
# Test this with no external boundary data

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install geopandas &> /dev/null
import os
import pandas as pd
import pickle
import geopandas as gpd
import numpy as np

# Autocorrelation and plotting modules
# !pip install pysal contextily &> /dev/null
import matplotlib.pyplot as plt
import seaborn
from pysal.viz import splot
from splot.esda import plot_moran

import contextily
import pandas as pd
from pysal.explore import esda
from pysal.lib import weights
from numpy.random import seed

os.chdir('/content/drive/MyDrive/shared/ssc22-case-comp/dataset/')
print(os.getcwd())
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# /usr/local/lib/python3.7/dist-packages/spaghetti/network.py:36: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(f"{dep_msg}", FutureWarning)
# /content/drive/MyDrive/shared/dataset

# %% [markdown]
# Here we perform spatial autocorrelation using the aggregated data.

# %%
# Load CD downlaod data
dat_path = './canada-census-division/CD-download-data.shp'

dat = gpd.read_file(dat_path)
print(dat.shape)
print(dat.columns)
dat.head(5)
# Out:
# (293, 20)
# Index(['CDUID', 'CDNAME', 'CDTYPE', 'PRUID', 'PRNAME', '2019-Q1', '2019-Q2',
#        '2019-Q3', '2019-Q4', '2020-Q1', '2020-Q2', '2020-Q3', '2020-Q4',
#        '2021-Q1', '2021-Q2', '2021-Q3', '2021-Q4', 'tests', 'DA_POP',
#        'geometry'],
#       dtype='object')
#   CDUID           CDNAME CDTYPE PRUID        PRNAME    2019-Q1    2019-Q2  \
# 0  4621  Division No. 21    CDR    46      Manitoba  10.969708  11.504049
# 1  4622  Division No. 22    CDR    46      Manitoba  42.902977  31.102748
# 2  4623  Division No. 23    CDR    46      Manitoba   7.367737   8.154834
# 3  4701  Division No.  1    CDR    47  Saskatchewan  14.791119  14.680140
# 4  4702  Division No.  2    CDR    47  Saskatchewan  16.695685  20.033315
#
#      2019-Q3    2019-Q4    2020-Q1    2020-Q2    2020-Q3    2020-Q4  \
# 0  12.178585  11.598048  31.078093  17.680161  32.997536  39.577115
# 1  31.654955  63.713872  22.245280  25.696649  30.131834  37.165333
# 2  10.676788  10.329840  18.924137  11.283153  59.781785  69.834849
# 3  19.249345  23.091277  21.493342  18.430462  16.796906  21.772634
# 4  21.169976  23.188939  23.552589  21.423277  24.913625  23.100039
#
#      2021-Q1    2021-Q2     2021-Q3    2021-Q4  tests     DA_POP  \
# 0  36.638628  68.453336   62.776182  95.403728   9685  1053890.0
# 1  66.576610  86.906071  102.148346  97.025587   4389  1096785.0
# 2  59.428820  77.856268   93.372450  97.945121   3235   266635.0
# 3  22.333091  49.550688   79.115720  67.320231  17296  1741640.0
# 4  21.547493  31.417196   51.642854  50.141588  11089  1076270.0
#
#                                             geometry
# 0  POLYGON ((5753862.131 2114062.380, 5752944.009...
# 1  POLYGON ((6204057.683 2107140.734, 6204737.266...
# 2  MULTIPOLYGON (((6039656.509 2636304.343, 60396...
# 3  POLYGON ((5422081.934 1612417.386, 5422521.154...
# 4  POLYGON ((5270212.334 1641442.671, 5270216.591...

# %%
dat.info() ## it looks like there are still null values.
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CDUID     293 non-null    object
#  1   CDNAME    293 non-null    object
#  2   CDTYPE    293 non-null    object
#  3   PRUID     293 non-null    object
#  4   PRNAME    293 non-null    object
#  5   2019-Q1   290 non-null    float64
#  6   2019-Q2   290 non-null    float64
#  7   2019-Q3   290 non-null    float64
#  8   2019-Q4   290 non-null    float64
#  9   2020-Q1   291 non-null    float64
#  10  2020-Q2   291 non-null    float64
#  11  2020-Q3   290 non-null    float64
#  12  2020-Q4   291 non-null    float64
#  13  2021-Q1   291 non-null    float64
#  14  2021-Q2   291 non-null    float64
#  15  2021-Q3   291 non-null    float64
#  16  2021-Q4   291 non-null    float64
#  17  tests     293 non-null    int64
#  18  DA_POP    293 non-null    float64
#  19  geometry  293 non-null    geometry
# dtypes: float64(13), geometry(1), int64(1), object(5)
# memory usage: 45.9+ KB

# %%
inds = np.unique(np.where(pd.isnull(dat['2021-Q4']))[0])
dat.loc[inds]
# Out:
#     CDUID     CDNAME CDTYPE PRUID   PRNAME  2019-Q1  2019-Q2  2019-Q3  \
# 291  6205   Keewatin    REG    62  Nunavut      NaN      NaN      NaN
# 292  6208  Kitikmeot    REG    62  Nunavut      NaN      NaN      NaN
#
#      2019-Q4  2020-Q1  2020-Q2  2020-Q3  2020-Q4  2021-Q1  2021-Q2  2021-Q3  \
# 291      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 292      NaN      NaN     3.92      NaN   17.948      NaN      NaN      NaN
#
#      2021-Q4  tests  DA_POP                                           geometry
# 291      NaN     15  3535.0  MULTIPOLYGON (((6193825.809 3390255.469, 61943...
# 292      NaN      2     0.0  MULTIPOLYGON (((6105932.626 3935743.411, 61062...

# %%
cond = dat['PRNAME']=='Nunavut'
dat[cond]
# Out:
#     CDUID     CDNAME CDTYPE PRUID   PRNAME  2019-Q1  2019-Q2  2019-Q3  \
# 290  6204     Baffin    REG    62  Nunavut      NaN      NaN      NaN
# 291  6205   Keewatin    REG    62  Nunavut      NaN      NaN      NaN
# 292  6208  Kitikmeot    REG    62  Nunavut      NaN      NaN      NaN
#
#      2019-Q4  2020-Q1  2020-Q2  2020-Q3  2020-Q4    2021-Q1   2021-Q2  \
# 290    53.06   32.034      NaN      NaN      NaN  15.615333  8.527091
# 291      NaN      NaN      NaN      NaN      NaN        NaN       NaN
# 292      NaN      NaN     3.92      NaN   17.948        NaN       NaN
#
#      2021-Q3    2021-Q4  tests   DA_POP  \
# 290  7.61125  14.778941    102  85875.0
# 291      NaN        NaN     15   3535.0
# 292      NaN        NaN      2      0.0
#
#                                               geometry
# 290  MULTIPOLYGON (((7020343.300 3239921.443, 70203...
# 291  MULTIPOLYGON (((6193825.809 3390255.469, 61943...
# 292  MULTIPOLYGON (((6105932.626 3935743.411, 61062...

# %%
with open('./python_canada-speed-data.p', 'rb') as file:
  canada = pickle.load(file)

# %%
dat2 = dat.drop(inds)

# %%
dat2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 291 entries, 0 to 290
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CDUID     291 non-null    object
#  1   CDNAME    291 non-null    object
#  2   CDTYPE    291 non-null    object
#  3   PRUID     291 non-null    object
#  4   PRNAME    291 non-null    object
#  5   2019-Q1   290 non-null    float64
#  6   2019-Q2   290 non-null    float64
#  7   2019-Q3   290 non-null    float64
#  8   2019-Q4   290 non-null    float64
#  9   2020-Q1   291 non-null    float64
#  10  2020-Q2   290 non-null    float64
#  11  2020-Q3   290 non-null    float64
#  12  2020-Q4   290 non-null    float64
#  13  2021-Q1   291 non-null    float64
#  14  2021-Q2   291 non-null    float64
#  15  2021-Q3   291 non-null    float64
#  16  2021-Q4   291 non-null    float64
#  17  tests     291 non-null    int64
#  18  DA_POP    291 non-null    float64
#  19  geometry  291 non-null    geometry
# dtypes: float64(13), geometry(1), int64(1), object(5)
# memory usage: 47.7+ KB

# %%
cols = np.append(np.array(dat2.columns[range(5,17)]), dat2.columns[19])
cols
# Out:
# array(['2019-Q1', '2019-Q2', '2019-Q3', '2019-Q4', '2020-Q1', '2020-Q2',
#        '2020-Q3', '2020-Q4', '2021-Q1', '2021-Q2', '2021-Q3', '2021-Q4',
#        'geometry'], dtype=object)

# %%
sub_dat = dat[cols]
# sub_dat = dat2[cols]
sub_dat.head()
# Out:
#      2019-Q1    2019-Q2    2019-Q3    2019-Q4    2020-Q1    2020-Q2  \
# 0  10.969708  11.504049  12.178585  11.598048  31.078093  17.680161
# 1  42.902977  31.102748  31.654955  63.713872  22.245280  25.696649
# 2   7.367737   8.154834  10.676788  10.329840  18.924137  11.283153
# 3  14.791119  14.680140  19.249345  23.091277  21.493342  18.430462
# 4  16.695685  20.033315  21.169976  23.188939  23.552589  21.423277
#
#      2020-Q3    2020-Q4    2021-Q1    2021-Q2     2021-Q3    2021-Q4  \
# 0  32.997536  39.577115  36.638628  68.453336   62.776182  95.403728
# 1  30.131834  37.165333  66.576610  86.906071  102.148346  97.025587
# 2  59.781785  69.834849  59.428820  77.856268   93.372450  97.945121
# 3  16.796906  21.772634  22.333091  49.550688   79.115720  67.320231
# 4  24.913625  23.100039  21.547493  31.417196   51.642854  50.141588
#
#                                             geometry
# 0  POLYGON ((5753862.131 2114062.380, 5752944.009...
# 1  POLYGON ((6204057.683 2107140.734, 6204737.266...
# 2  MULTIPOLYGON (((6039656.509 2636304.343, 60396...
# 3  POLYGON ((5422081.934 1612417.386, 5422521.154...
# 4  POLYGON ((5270212.334 1641442.671, 5270216.591...

# %%
f, ax = plt.subplots(1, figsize=(9,9))
sub_dat.plot(column = '2021-Q4',
             cmap='viridis',
             scheme='quantiles',
             k=5,
             edgecolor='white',
             linewidth=0,
             alpha=0.75,
             legend=True,
             legend_kwds={'loc':2},
             ax=ax)

contextily.add_basemap(ax, 
                       crs=sub_dat.crs, 
                       source=contextily.providers.Stamen.TerrainBackground
                      )
ax.set_axis_off()

# %%
f, ax = plt.subplots(1, figsize=(9,9))
sub_dat.plot(column = '2019-Q1',
             cmap='viridis',
             scheme='quantiles',
             k=5,
             edgecolor='white',
             linewidth=0,
             alpha=0.75,
             legend=True,
             legend_kwds={'loc':2},
             ax=ax)

contextily.add_basemap(ax, 
                       crs=sub_dat.crs, 
                       source=contextily.providers.Stamen.TerrainBackground
                      )
ax.set_axis_off()

# %% [markdown]
# ## Apply global autocorrelation

# %%
# Global autocorrelation

# Smooths out the borders by the k nearest neighbours

w = weights.KNN.from_dataframe(sub_dat, k=5) # larger the k, smoother the boundaries

w.transform = 'R' # row-standardization

sub_dat['2021-Q4_lag'] = weights.spatial_lag.lag_spatial(w, sub_dat['2021-Q4'])


## Plot 
f, axs = plt.subplots(1, 2, figsize=(12, 6))
ax1, ax2 = axs

sub_dat.plot(column='2021-Q4', cmap='viridis', scheme='quantiles',
        k=5, 
        edgecolor='white', linewidth=0., alpha=0.75, legend=True, ax=ax1,
        figsize=(12,6))
ax1.set_axis_off()
ax1.set_title("download mbps")
contextily.add_basemap(ax1, 
                       crs=sub_dat.crs, 
                       source=contextily.providers.Stamen.TerrainBackground,
                       
                      )

sub_dat.plot(column='2021-Q4_lag', cmap='viridis', scheme='quantiles',
        k=5, edgecolor='white', linewidth=0., alpha=0.75, legend=True, ax=ax2,
        figsize=(12,6))
ax2.set_axis_off()
ax2.set_title("download mbps - Spatial Lag")
contextily.add_basemap(ax2, 
                       crs=sub_dat.crs, 
                       source=contextily.providers.Stamen.TerrainBackground,
                       
                      )

plt.show()

# %%
# binary case: mbps < 50

sub_dat['slow'] = (sub_dat['2021-Q4'] < 50).astype(int)
sub_dat[['2021-Q4', 'slow']].tail()
# Out:
#        2021-Q4  slow
# 288  87.262300     0
# 289  78.829696     0
# 290  14.778941     1
# 291        NaN     0
# 292        NaN     0

# %%
f, ax = plt.subplots(1, figsize=(9, 9))
sub_dat.plot(ax=ax, column='slow', categorical=True, legend=True, 
        edgecolor='0.5', linewidth=0.25, cmap='Set3', 
        figsize=(9, 9));
ax.set_axis_off()
ax.set_title('Download speed < 50mbps')
plt.axis('equal')
plt.show()

# %%
# Would we have something more interesting if we use DA instead?
